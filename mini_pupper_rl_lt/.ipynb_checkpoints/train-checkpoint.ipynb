# %% [markdown]
# ### Locomotion-Transformer
# ### How to
# 1. Gazebo を起動
# $ __NV_PRIME_RENDER_OFFLOAD=1 __GLX_VENDOR_LIBRARY_NAME=nvidia ros2 launch mini_pupper_simulation bringup.launch.py launch_twist_converter:=False

# %%
import os
import sys
# torchをインポートする前に設定
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
from gazebo_env import MiniPupperEnv,MAX_ACTION_RAD
from stable_baselines3 import PPO
import rclpy
import torch

import torch as th
import torch.nn as nn
from stable_baselines3.common.policies import ActorCriticPolicy
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

# %%
rclpy.init()
env = MiniPupperEnv()

cont_f=False

if MAX_ACTION_RAD==1.0:
    use_sde=True
    sde_sample_freq=16
    out_dir="outs-10"
else:
    use_sde=True       # add by nishi 2026.8.3
    sde_sample_freq=4   # add by nishi 2026.8.3
    out_dir="outs-05"
    

if not cont_f:
    reset_num_timesteps=True
else:
    reset_num_timesteps=False

# %%
class MiniPupperLocomotionTransformer(BaseFeaturesExtractor):
    def __init__(self, observation_space, features_dim=256):
        super().__init__(observation_space, features_dim)
        
        self.num_legs = 4
        # 【変更】1脚あたり：位置(3) + 速度(3) = 計6次元の情報を持つ
        self.features_per_leg = 6  
        self.token_dim = 64      
        
        # --- 各入力パーツをトークンに変換する層 ---
        self.cmd_embed = nn.Linear(3, self.token_dim)      
        self.leg_embed = nn.Linear(self.features_per_leg, self.token_dim) # 【変更】入力3➔6次元へ
        self.quat_embed = nn.Linear(4, self.token_dim)     
        
        # --- Transformerエンコーダー（構成は維持：計6トークン） ---
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=self.token_dim, 
            nhead=4,              
            dim_feedforward=128,  
            batch_first=True,
            activation="relu"
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)
        
        # --- 最終出力をまとめる層 ---
        total_tokens = 1 + self.num_legs + 1  # 6トークン
        self.output_layer = nn.Sequential(
            nn.Linear(total_tokens * self.token_dim, features_dim),
            nn.ReLU()
        )

    def forward(self, observations):
        batch_size = observations.shape[0]
        
        # --- 1. 【変更】31次元のインデックスに合わせて厳密にスライス ---
        # 構成: [0~2: cmd_vel] [3~14: joint_pos] [15~26: joint_vel] [27~30: quat]
        cmd_vel_data = observations[:, 0:3]
        joint_pos    = observations[:, 3:15]
        joint_vel    = observations[:, 15:27] # 【追加】関節速度をスライス
        quat_data    = observations[:, 27:31] # 【変更】インデックスのズレを修正
        
        # --- 2. 各パーツをトークン化 ---
        cmd_token = self.cmd_embed(cmd_vel_data).unsqueeze(1)
        
        # 【追加】同じ脚の「位置」と「速度」をセットにして4本の脚に分解する
        # [batch, 12] -> [batch, 4, 3]
        leg_pos_split = joint_pos.view(batch_size, self.num_legs, 3)
        leg_vel_split = joint_vel.view(batch_size, self.num_legs, 3)
        
        # 脚ごとに位置と速度を結合して [batch, 4, 6] の形にする
        # これにより「同じ脚の現在の状態」が1つにまとまります
        legs_combined = th.cat([leg_pos_split, leg_vel_split], dim=2)
        
        # 4本の脚（各6次元）を並列でトークン化 -> [batch, 4, token_dim]
        leg_tokens = self.leg_embed(legs_combined)
        
        quat_token = self.quat_embed(quat_data).unsqueeze(1)
        
        # --- 3. トランスフォーマーへの入力シーケンス結合 ---
        tokens = th.cat([cmd_token, leg_tokens, quat_token], dim=1)
        
        # --- 4. Transformer実行 ➔ 5. フラット化して出力 ---
        transformer_out = self.transformer(tokens)  
        flat_out = transformer_out.view(batch_size, -1)
        return self.output_layer(flat_out)

# %%
# 1. デバイスの定義 (すでに定義済みの場合は不要)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = "cpu"

#model = PPO(
#    ActorCriticPolicy, # MlpPolicyの代わりにActorCriticPolicyを指定
#    env,               # あなたの作成したMini PupperのGym環境
#    policy_kwargs=policy_kwargs,
#    verbose=1,
#    # 他のハイパーパラメータ（learning_rate等）は今の設定のままでOK
#)

# ネットワーク構造のカスタマイズ (おすすめ設定)
policy_kwargs_old = dict(
    net_arch=dict(
        pi=[256, 256],  # 政策（Policy）ネットワーク: 256×2層
        vf=[256, 256]   # 価値（Value）ネットワーク: 256×2層
    )
)

# 現在のMlpPolicyの指定をベースに、policy_kwargsを追記します
policy_kwargs = dict(
    features_extractor_class=MiniPupperLocomotionTransformer,
    features_extractor_kwargs=dict(features_dim=256),
    # 必要に応じて、Transformerの後のActor/Criticそれぞれの全結合層(頭)の厚みを指定
    #net_arch=dict(pi=[128, 128], vf=[128, 128]) 
    net_arch=dict(pi=[256, 256], vf=[256, 256]) 
)
    
if not cont_f:
    if True:
        model = PPO(
            ActorCriticPolicy,           # "MlpPolicy" からクラスオブジェクトに変更
            env,
            policy_kwargs=policy_kwargs,
            learning_rate=1.5e-4,        # Transformer向けに少しだけ慎重に設定（2e-4などでも可）
            n_steps=4096,              
            batch_size=128,            
            n_epochs=10,               
            gamma=0.99,                
            gae_lambda=0.95,           
            clip_range=0.2,            
            ent_coef=0.05,             # 積極的な探索設定を維持
            verbose=1,
            device=device,
            #use_sde=True,                # SDEとの相性も抜群です
            #sde_sample_freq=4,   
            use_sde=use_sde,       # add by nishi 2026.8.3
            sde_sample_freq=sde_sample_freq,   # add by nishi 2026.8.3
        )

    if False:
        model = PPO(
            ActorCriticPolicy,
            env,
            policy_kwargs=policy_kwargs,
            learning_rate=3e-4,        # 4足歩行で最も安定する学習率
            n_steps=4096,              # Gazeboのデータをまとめて学習に使う単位（大きめが安定）
            batch_size=128,            # 1回の最適化で計算するバッチサイズ
            n_epochs=10,               # 集めたデータで何回繰り返し学習するか
            gamma=0.99,                # 将来の報酬の割引率
            gae_lambda=0.95,           # 報酬のばらつきを抑える設定
            clip_range=0.2,            # 方策の変化を制限して学習を安定させる
            #ent_coef=0.01,             # ロボットが色々な動きを試す（探索）ための味付け
            ent_coef=0.05,             # デフォルトの 0.0 や 0.01 から、0.05〜0.1 程度に上げてみる
            verbose=1,
            device=device,
            use_sde=True,       # add by nishi 2026.8.3
            sde_sample_freq=4,   # add by nishi 2026.8.3
            #sde_sample_freq=16,   # add by nishi 2026.8.3
        )
else:
    # policy_kwargs は不要（保存されたファイルから自動で読み込まれます）
    model = PPO.load(
        os.path.join(out_dir, "ppo_minipupper_test_2"),
        #"outs/ppo_minipupper_test_1",
        env=env,
        device=device
    )

# %%
model.learn(
    #total_timesteps=500000,
    #total_timesteps=1000,
    #total_timesteps=3000
    #total_timesteps=10000,
    #total_timesteps=50000,
    total_timesteps=200000,
    #total_timesteps=300000,
    reset_num_timesteps=reset_num_timesteps
)

# %%
model.save(os.path.join(out_dir, "ppo_minipupper_test_latest"))
